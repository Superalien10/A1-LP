# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %% [markdown]
# #QUESTÃO 1 - GRUPO 1

# %% [markdown]
# ### Músicas menos ouvidas na carreira

# %%
#Músicas menos ouvidas da carreira do Seu Jorge
df = pd.read_csv("./dataframe_menos_ouvidas.csv") 
fig, ax=plt.subplots(figsize=(12,8))
df1 = df.sort_values('Visualizações') #inverter a ordem começando do menor para o maior valor
sns.barplot(data=df1, x= "Visualizações", y="Música",
            palette = ("Paired")).set(title = "Músicas Menos Ouvidas")
plt.savefig("menos_ouvidas.png")

# %% [markdown]
# ### Músicas mais ouvidas na carreira

# %%
#Músicas mais ouvidas da carreira do Seu Jorge
df2 = pd.read_csv("./mais_ouvidas.csv")
fig, ax=plt.subplots(figsize=(16,8))
sns.barplot(data=df2, x="Visualizações", y="Música", 
            palette = ("Blues_r")).set(title = "Músicas Mais Ouvidas") 
plt.savefig("mais_ouvidas.png")

# %% [markdown]
# #QUESTÃO 2 - GRUPO 1

# %% [markdown]
# ##1) Álbum América Brasil

# %% [markdown]
# Antes de gerar separadamente os gráficos referentes as músicas mais longas e mais curtas, fizemos um gráfico com todas as músicas do álbum para facilitar a visualização do número de músicas total captado pelo dataframe, para posteriormente dividir em músicas mais longas - a partir do método head() - e músicas mais curtas - a partir do método tail() - num gráfico que foi ordenado de maneira crescente através do método sort.values().

# %%
#Álbum América Brasil
dfAB_d = pd.read_csv("./dataframe_duração_América Brasil.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAB_d, x="Duração", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil", xlabel = "Duração em Segundos")
# Out:
# [Text(0.5, 0, 'Duração em Segundos'), Text(0.5, 1.0, 'Álbum América Brasil')]

# %% [markdown]
# ### Músicas mais longas

# %%
#Álbum América Brasil Mais Longas
dfAB_d_mais_longas= dfAB_d.head(4)
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfAB_d_mais_longas, x="Duração", y="Música",
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Músicas Mais Longas",
                                         xlabel = "Duração em Segundos")
plt.savefig("mais_longas_AméricaBrasil.png")

# %% [markdown]
# ### Músicas mais curtas

# %%
#Álbum América Brasil Mais Curtas
dfAB_d_mais_curtas= dfAB_d.tail(3)
dfAB_d_mais_curtas2 = dfAB_d_mais_curtas.sort_values("Duração")
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfAB_d_mais_curtas2, x="Duração", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Músicas Mais Curtas", xlabel = "Duração em Segundos")
plt.savefig("mais_curtas_AméricaBrasil.png")

# %% [markdown]
# ##2) Álbum América Brasil Ao Vivo

# %% [markdown]
# Antes de gerar separadamente os gráficos referentes as músicas mais longas e mais curtas, fizemos um gráfico com todas as músicas do álbum para facilitar a visualização do número de músicas total captado pelo dataframe, para posteriormente dividir em músicas mais longas - a partir do método head() - e músicas mais curtas - a partir do método tail() - num gráfico que foi ordenado de maneira crescente através do método sort.values().

# %%
dfABv_d = pd.read_csv("./dataframe_duração_América Brasil (Ao Vivo).csv")
fig, ax=plt.subplots(figsize=(15,8))
sns.barplot(data=dfABv_d, x="Duração", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo", xlabel = "Duração em Segundos")
# Out:
# [Text(0.5, 0, 'Duração em Segundos'),
#  Text(0.5, 1.0, 'Álbum América Brasil Ao Vivo')]

# %% [markdown]
# ### Músicas mais longas

# %%
#Álbum América Brasil Ao Vivo Mais Longas
dfABv_d_mais_longas = dfABv_d.head(4)
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfABv_d_mais_longas, x="Duração", y="Música",
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Músicas Mais Longas", xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_AméricaBrasilAoVivo.png")

# %% [markdown]
# ### Músicas mais curtas

# %%
#Álbum América Brasil Ao Vivo Mais Curtas
dfABv_d_mais_curtas= dfABv_d.tail(3)
dfABv_d_mais_curtas2 = dfABv_d_mais_curtas.sort_values("Duração")
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(data=dfABv_d_mais_curtas2, x="Duração", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Músicas Mais Curtas",
                                        xlabel = "Duração em Segundos") 
plt.savefig("mais_curtas_AméricaBrasilAovivo.png")

# %% [markdown]
# ##3) Álbum Ana e Jorge

# %% [markdown]
# ###Músicas mais longas e mais curtas

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum Ana e Jorge Mais Longas e Mais Curtas
dfAJ_d = pd.read_csv("./dataframe_duração_Ana e Jorge.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAJ_d, x="Duração", y="Música", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge", xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_AnaeJorge.png")

# %% [markdown]
# ##4) Álbum Cru

# %% [markdown]
# ### Músicas mais longas e mais curtas

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum Cru Mais Longas e Mais curtas
dfC_d= pd.read_csv("./dataframe_duração_Cru.csv")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfC_d, x="Duração", y="Música",
            palette = ("Purples_r")).set(title = "Álbum Cru ",  xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_Cru.png")

# %% [markdown]
# ## 5) Álbum MTV Apresenta Seu Jorge

# %% [markdown]
# ###Músicas mais longas e mais curtas

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum MTV Apresenta Seu Jorge Mais Longas e Mais Curtas
dfMTV_d = pd.read_csv("./dataframe_duração_MTV Apresenta Seu Jorge.csv")
fig, ax=plt.subplots(figsize=(18,5))
sns.barplot(data=dfMTV_d, x="Duração", y="Música", 
            palette = ("RdBu_r")).set(title = "MTV Apresenta Seu Jorge", xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_MTVApresentaSeuJorge.png")

# %% [markdown]
# ##6) Álbum Músicas Para Churrasco (vol.1)

# %% [markdown]
# Antes de gerar separadamente os gráficos referentes as músicas mais longas e mais curtas, fizemos um gráfico com todas as músicas do álbum para facilitar a visualização do número de músicas total captado pelo dataframe, para posteriormente dividir em músicas mais longas - a partir do método head() - e músicas mais curtas - a partir do método tail() - num gráfico que foi ordenado de maneira crescente através do método sort.values().

# %%
#Álbum Músicas Para Churrasco (vol.1)
dfMC_d = pd.read_csv("./dataframe_duração_Músicas Para Churrasco (vol.1).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMC_d, x="Duração", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1)", xlabel = "Duração em Segundos")
# Out:
# [Text(0.5, 0, 'Duração em Segundos'),
#  Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.1)')]

# %% [markdown]
# ### Músicas mais longas

# %%
#Álbum Músicas Para Churrasco (vol.1) músicas mais longas
dfMC_d_mais_longas = dfMC_d.head(3)
fig, ax=plt.subplots(figsize=(18,6))
sns.barplot(data=dfMC_d_mais_longas, x="Duração", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Músicas Mais Longas", xlabel = "Duração em Segundos")
plt.savefig("mais_longas_MúsicasParaChurrasco(vol1).png")

# %% [markdown]
# ### Músicas mais curtas

# %%
#Álbum Músicas Para Churrasco (vol.1) músicas mais curtas
dfMC_d_mais_curtas = dfMC_d.tail(3)
dfMC_d_mais_curtas2 = dfMC_d_mais_curtas.sort_values("Duração")
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfMC_d_mais_curtas2, x="Duração", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Músicas Mais Curtas",
                                      xlabel = "Duração em Segundos") 
plt.savefig("mais_curtas_MúsicasParaChurrasco(vol1).png")

# %% [markdown]
# ## 7) Álbum Músicas Para Churrasco (vol.2)

# %% [markdown]
# Antes de gerar separadamente os gráficos referentes as músicas mais longas e mais curtas, fizemos um gráfico com todas as músicas do álbum para facilitar a visualização do número de músicas total captado pelo dataframe, para posteriormente dividir em músicas mais longas - a partir do método head() - e músicas mais curtas - a partir do método tail() - num gráfico que foi ordenado de maneira crescente através do método sort.values().

# %%
#Músicas Para Churrasco (vol.2)
dfMC2_d = pd.read_csv("./dataframe_duração_Músicas Para Churrasco (vol.2).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMC2_d, x="Duração", y="Música", 
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2)",  xlabel = "Duração em Segundos")
# Out:
# [Text(0.5, 0, 'Duração em Segundos'),
#  Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.2)')]

# %% [markdown]
# ### Músicas mais longas

# %%
#Músicas Para Churrasco (vol.2) músicas mais longas
dfMC2_d = pd.read_csv("./dataframe_duração_Músicas Para Churrasco (vol.2).csv")
dfMC2_d_mais_longas = dfMC2_d.head(4)
fig, ax=plt.subplots(figsize=(14,8))
sns.barplot(data=dfMC2_d_mais_longas, x="Duração", y="Música",
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Músicas Mais Longas",  xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_MúsicasParaChurrasco(vol2).png")

# %% [markdown]
# ### Músicas mais curtas

# %%
#Músicas Para Churrasco (vol.2) músicas mais curtas
dfMC2_d_mais_curtas = dfMC2_d.tail(3)
dfMC2_d_mais_curtas2 = dfMC2_d_mais_curtas.sort_values("Duração")
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfMC2_d_mais_curtas2, x="Duração", y="Música",
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Músicas Mais Curtas",
                                      xlabel = "Duração em Segundos") 
plt.savefig("mais_curtas_MúsicasParaChurrasco(vol2).png")

# %% [markdown]
# ## 8) Álbum Night Dreamer Direct-to-disc Sessions

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum Night Dreamer Direct-to-disc Sessions Mais Longas e Mais Curtas
dfND_d = pd.read_csv("./dataframe_duração_Night Dreamer Direct-to-disc Sessions.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfND_d, x="Duração", y="Música", 
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions",xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_NightDreamer.png")

# %% [markdown]
# ### 9) Álbum Samba Esporte Fino

# %% [markdown]
# ###Músicas mais longas e mais curtas

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum Samba Esporte Fino Mais Longas e Mais Curtas
dfSEF_d = pd.read_csv("./dataframe_duração_Samba Esporte Fino.csv")
fig, ax=plt.subplots(figsize=(20,6))
sns.barplot(data=dfSEF_d, x="Duração", y="Música", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino",
            xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_SambaEsporteFino.png")

# %% [markdown]
# ## 10) Álbum Perfil

# %% [markdown]
# Neste álbum o dataframe para duração contém poucas músicas do álbum, por conta disso, optamos por fazer apenas um gráfico para demonstrar as músicas mais longas e mais curtas, com a finalidade de evitar redundância na visualização dos dados.

# %%
#Álbum Perfil Músicas Mais Longas e Mais Novas
dfP = pd.read_csv("./dataframe_duração_Perfil.csv")
fig, ax=plt.subplots(figsize=(14,8))
sns.barplot(data=dfP, x="Duração", y="Música", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil", xlabel = "Duração em Segundos") 
plt.savefig("mais_longas_mais_curtas_Perfil.png")

# %% [markdown]
# ## 11) Álbum The Life Aquatic Studio

# %% [markdown]
# Neste álbum, o dataframe duração continha apenas uma música, por conta disso, optamos por omitir esse gráfico.

# %% [markdown]
# #QUESTÃO 3 - GRUPO 1

# %% [markdown]
# Nesta questão, todos os álbuns contém o mesmo procedimento, similiar ao da questão de anterior: antes de gerar separadamente os gráficos referentes as músicas mais longas e mais curtas, fizemos um gráfico com todas as músicas do álbum para facilitar a visualização do número de músicas total captado pelo dataframe, para posteriormente dividir em músicas mais ouvidas - a partir do método head() - e músicas menos ouvidas - a partir do método tail() - num gráfico que foi ordenado de maneira crescente através do método sort.values(). Em relação a questão anterior, mantivemos a mesma paleta de cores para os albúns, entretanto, para diferenciar os gráficos optamos por inverter os eixos.

# %% [markdown]
# ##1) Álbum América Brasil

# %%
#Álbum América Brasil
dfAB = pd.read_csv("./dataframe_visualizacoes_América Brasil.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAB, x="Visualizações", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil")
# Out:
# [Text(0.5, 1.0, 'Álbum América Brasil')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum América Brasil Mais Ouvidas
dfAB_mais_ouvidas = dfAB.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAB_mais_ouvidas, x="Música", y="Visualizações",
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Mais Ouvidas")
plt.savefig("mais_ouvidas_AméricaBrasil.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum América Brasil Menos Ouvidas
dfAB_menos_ouvidas = dfAB.tail(5)
dfAB_menos_ouvidas2 = dfAB_menos_ouvidas.sort_values('Visualizações')
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAB_menos_ouvidas2, x="Música", y="Visualizações", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Menos Ouvidas") 
plt.savefig("menos_ouvidas_AméricaBrasil.png")

# %% [markdown]
# ##2) Álbum América Brasil Ao Vivo

# %%
#Álbum América Brasil ao vivo 
dfABv = pd.read_csv("./dataframe_visualizacoes_América Brasil (Ao Vivo).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfABv, x="Visualizações", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo")
# Out:
# [Text(0.5, 1.0, 'Álbum América Brasil Ao Vivo')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum América Brasil Ao Vivo Mais Ouvidas
dfABv_mais_ouvidas = dfABv.head(4)
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfABv_mais_ouvidas, x="Música", y="Visualizações", palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Mais Ouvidas")
plt.savefig("mais_ouvidas_AméricaBrasilAoVivo.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum América Brasil Ao Vivo Menos Ouvidas
dfABv_menos_ouvidas = dfABv.tail(3)
dfABv_menos_ouvidas2 = dfABv_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(8,6))
sns.barplot(data=dfABv_menos_ouvidas2, x="Música", y="Visualizações",
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Menos Ouvidas")
# Out:
# [Text(0.5, 1.0, 'Álbum América Brasil Ao Vivo - Menos Ouvidas')]

# %% [markdown]
# ##3) Álbum Ana e Jorge

# %%
#Álbum Ana e Jorge
dfAJ = pd.read_csv("./dataframe_visualizacoes_Ana e Jorge.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAJ, x="Visualizações", y="Música", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge")
# Out:
# [Text(0.5, 1.0, 'Álbum Ana e Jorge')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Ana e Jorge Mais Ouvidas
dfAJ = pd.read_csv("./dataframe_visualizacoes_Ana e Jorge.csv")
dfAJ_mais_ouvidas = dfAJ.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAJ_mais_ouvidas, x="Música", y="Visualizações", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge - Mais Ouvidas") 
plt.savefig("mais_ouvidas_AnaeJorge.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Ana e Jorge Menos Ouvidas
dfAJ_menos_ouvidas = dfAJ.tail(5)
dfAJ_menos_ouvidas2 = dfAJ_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAJ_menos_ouvidas2, x="Música", y="Visualizações",
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge - Menos Ouvidas") 
plt.savefig("menos_ouvidas_AnaeJorge.png")

# %% [markdown]
# ##4) Álbum Cru

# %%
#Álbum Cru
dfC= pd.read_csv("./dataframe_visualizacoes_Cru.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfC, x="Visualizações", y="Música", 
            palette = ("Purples_r")).set(title = "Álbum Cru")
# Out:
# [Text(0.5, 1.0, 'Álbum Cru')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Cru Mais Ouvidas 
dfC_mais_ouvidas = dfC.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfC_mais_ouvidas, x="Música", y="Visualizações", 
            palette = ("Purples_r")).set(title = "Álbum Cru - Mais Ouvidas")
plt.savefig("mais_ouvidas_Cru.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Cru Mais Ouvidas 
dfC_menos_ouvidas = dfC.tail(5)
dfC_menos_ouvidas2 = dfC_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfC_menos_ouvidas2, x="Música", y="Visualizações", 
            palette = ("Purples_r")).set(title = "Álbum Cru - Menos Ouvidas") 
plt.savefig("menos_ouvidas_Cru.png")

# %% [markdown]
# ## 5) Álbum MTV Apresenta Seu Jorge

# %%
#Álbum MTV Apresenta Seu Jorge
dfMTV = pd.read_csv("./dataframe_visualizacoes_MTV Apresenta Seu Jorge.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMTV, x="Visualizações", y="Música", 
            palette = ("RdBu_r")).set(title = "MTV Apresenta Seu Jorge")
# Out:
# [Text(0.5, 1.0, 'MTV Apresenta Seu Jorge')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum MTV Apresenta Seu Jorge Mais Ouvidas
dfMTV = pd.read_csv("./dataframe_visualizacoes_MTV Apresenta Seu Jorge.csv")
dfMTV_mais_ouvidas = dfMTV.head(4)
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfMTV_mais_ouvidas, x="Música", y="Visualizações", 
            palette = ("RdBu_r")).set(title = "Álbum MTV Apresenta Seu Jorge - Mais Ouvidas") 
plt.savefig("mais_ouvidas_MTVApresentaSeuJorge.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum MTV Apresenta Seu Jorge Menos Ouvidas
dfMTV_menos_ouvidas = dfMTV.tail(4)
dfMTV_menos_ouvidas2 = dfMTV_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfMTV_menos_ouvidas2,x="Música", y="Visualizações",
            palette = ("RdBu_r")).set(title = "Álbum MTV Apresenta Seu Jorge - Menos Ouvidas")
plt.savefig("menos_ouvidas_MTVApresentaSeuJorge.png")

# %% [markdown]
# ##6) Álbum Músicas Para Churrasco (vol.1)

# %%
#Álbum Músicas Para Churrasco (vol.1)
dfMC = pd.read_csv("./dataframe_visualizacoes_Músicas Para Churrasco (vol.1).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMC, x="Visualizações", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1)")
# Out:
# [Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.1)')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Músicas Para Churrasco (vol.1) Mais Ouvidas
dfMC = pd.read_csv("./dataframe_visualizacoes_Músicas Para Churrasco (vol.1).csv")
dfMC_mais_ouvidas = dfMC.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfMC_mais_ouvidas, x="Música", y="Visualizações", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) Mais Ouvidas")
plt.savefig("mais_ouvidas_MusicasParaChurrasco(vol1).png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Músicas Para Churrasco (vol.1) Menos Ouvidas
dfMC_menos_ouvidas = dfMC.tail(5)
dfMC_menos_ouvidas2 = dfMC_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfMC_menos_ouvidas2, x="Música", y="Visualizações",
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Menos Ouvidas") 
plt.savefig("menos_ouvidas_MusicasParaChurrasco(vol1).png")

# %% [markdown]
# ## 7) Álbum Músicas Para Churrasco (vol.2)

# %%
#Músicas Para Churrasco (vol.2)
dfMC2 = pd.read_csv("./dataframe_visualizacoes_Músicas Para Churrasco (vol.2).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMC2, x="Visualizações", y="Música", 
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2)")
# Out:
# [Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.2)')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Músicas Para Churrasco (vol.2) Mais Ouvidas
dfMC2 = pd.read_csv("./dataframe_visualizacoes_Músicas Para Churrasco (vol.2).csv")
dfMC2_mais_ouvidas = dfMC2.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfMC2_mais_ouvidas, x="Música", y="Visualizações",
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Mais Ouvidas") 
plt.savefig("mais_ouvidas_MusicasParaChurrasco(vol2).png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Músicas Para Churrasco (vol.2) Menos Ouvidas
dfMC2_menos_ouvidas = dfMC2.tail(5)
dfMC2_menos_ouvidas2 = dfMC2_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfMC2_menos_ouvidas2, x="Música", y="Visualizações",
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Menos Ouvidas") 
plt.savefig("menos_ouvidas_MusicasParaChurrasco(vol2).png")

# %% [markdown]
# ## 8) Álbum Night Dreamer Direct-to-disc Sessions

# %%
#Álbum Night Dreamer Direct-to-disc Sessions
dfND = pd.read_csv("./dataframe_visualizacoes_Night Dreamer Direct-to-disc Sessions.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfND, x="Visualizações", y="Música", 
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions")
# Out:
# [Text(0.5, 1.0, 'Álbum Night Dreamer Direct-to-disc Sessions')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Night Dreamer Direct-to-disc Sessions Mais Ouvidas
dfND = pd.read_csv("./dataframe_visualizacoes_Night Dreamer Direct-to-disc Sessions.csv")
dfND_mais_ouvidas = dfND.head(4)
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfND_mais_ouvidas, x="Música", y="Visualizações",
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions - Mais Ouvidas") 
plt.savefig("mais_ouvidas_NightDreamer.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Night Dreamer Direct-to-disc Sessions Menos Ouvidas
dfND_menos_ouvidas = dfND.tail(3)
dfND_menos_ouvidas2 = dfND_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(8,6))
sns.barplot(data=dfND_menos_ouvidas2, x="Música", y="Visualizações", 
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions - Menos Ouvidas")
plt.savefig("menos_ouvidas_NightDreamer.png")

# %% [markdown]
# ## 9) Álbum Samba Esporte Fino

# %%
#Álbum Samba Esporte Fino
dfSEF = pd.read_csv("./dataframe_visualizacoes_Samba Esporte Fino.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfSEF, x="Visualizações", y="Música", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino")
# Out:
# [Text(0.5, 1.0, 'Álbum Samba Esporte Fino')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Samba Esporte Fino Mais Ouvidas
dfSEF = pd.read_csv("./dataframe_visualizacoes_Samba Esporte Fino.csv")
dfSEF_mais_ouvidas = dfSEF.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfSEF_mais_ouvidas, x="Música", y="Visualizações", 
            palette = ("coolwarm_r")).set(title = "Álbum  Samba Esporte Fino - Mais Ouvidas") 
plt.savefig("mais_ouvidas_SambaEsporteFino.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Samba Esporte Fino Menos Ouvidas
dfSEF_menos_ouvidas = dfSEF.tail(4)
dfSEF_menos_ouvidas2 = dfSEF_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfSEF_menos_ouvidas2, x="Música", y="Visualizações", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino - Menos Ouvidas") 
plt.savefig("menos_ouvidas_SambaEsporteFino.png")

# %% [markdown]
# ## 10) Álbum Perfil

# %%
#Álbum Perfil
dfP = pd.read_csv("./dataframe_visualizacoes_Perfil.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfP, x="Visualizações", y="Música", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil")
# Out:
# [Text(0.5, 1.0, 'Álbum Perfil')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum Perfil Mais Ouvidas
dfP = pd.read_csv("./dataframe_visualizacoes_Perfil.csv")
dfP_mais_ouvidas = dfP.head(5)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfP_mais_ouvidas, x="Música", y="Visualizações",
            palette = ("OrRd_r")).set(title = "Álbum Perfil - Mais Ouvidas") 
plt.savefig("mais_ouvidas_Perfil.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum Perfil Menos Ouvidas
dfP_menos_ouvidas = dfP.tail(5)
dfP_menos_ouvidas2 = dfP_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfP_menos_ouvidas2, x="Música", y="Visualizações", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil - Menos Ouvidas") 
plt.savefig("menos_ouvidas_Perfil.png")

# %% [markdown]
# ##11) Álbum The Life Aquatic Studio

# %%
#Álbum The Life Aquatic Studio Sessions
dfLA = pd.read_csv("./dataframe_visualizacoes_The Life Aquatic Studio Sessions.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfLA, x="Visualizações", y="Música", 
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions")
# Out:
# [Text(0.5, 1.0, 'Álbum The Life Aquatic Studio Sessions')]

# %% [markdown]
# ### Músicas mais ouvidas

# %%
#Álbum The Life Aquatic Studio Sessions Mais Ouvidas
dfLA = pd.read_csv("./dataframe_visualizacoes_The Life Aquatic Studio Sessions.csv")
dfLA_mais_ouvidas = dfLA.head(7)
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(data=dfLA_mais_ouvidas, x="Música", y="Visualizações",
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions - Mais Ouvidas")
plt.savefig("mais_ouvidas_TheLifeAquaticStudioSessions.png")

# %% [markdown]
# ### Músicas menos ouvidas

# %%
#Álbum The Life Aquatic Studio Sessions Menos Ouvidas
dfLA_menos_ouvidas = dfLA.tail(7)
dfLA_menos_ouvidas2 = dfLA_menos_ouvidas.sort_values("Visualizações")
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(data=dfLA_menos_ouvidas2,x="Música", y="Visualizações",
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions - Menos Ouvidas") 
plt.savefig("menos_ouvidas_TheLifeAquaticStudioSessions.png")

# %% [markdown]
# #QUESTÃO 4 - GRUPO 1

# %% [markdown]
# Nesta questão, utilizamos dois dataframes, um com as músicas mais curtas e outro com as músicas mais longas da carreira do Seu Jorge. No gráfico das músicas mais curtas, assim como nas outras questões, ordenamos de maneira crescente, enquanto no gráfico de músicas mais longas, ordenamos de maneira decrescente.

# %% [markdown]
# ##Músicas mais longas da carreira

# %%
#Músicas mais longas da carreira do Seu Jorge
df_mais_longas = pd.read_csv("./dataframe_mais_longas.csv")
fig, ax=plt.subplots(figsize=(12,8)) 
sns.barplot(data=df_mais_longas, x= "Duração", y="Música", 
            palette = ("Blues_r")).set(title = "Músicas Mais Longas da Carreira do Seu Jorge", 
                                       xlabel = "Duração em Segundos")
plt.savefig("mais_longas_carreira.png")

# %% [markdown]
# ##Músicas mais curtas da carreira

# %%
#Músicas mais curtas da carreira do Seu Jorge
df_mais_curtas = pd.read_csv("./dataframe_mais_curtas.csv")
fig, ax=plt.subplots(figsize=(15,8)) 
df_mais_curtas2 = df_mais_curtas.sort_values('Duração') #inverter a ordem começando do menor para o maior valor
sns.barplot(data=df_mais_curtas2, x= "Duração", y="Música", 
            palette = ("Paired")).set(title = "Músicas Mais Curtas da Carreira do Seu Jorge", 
                                      xlabel = "Duração em Segundos")
plt.savefig("mais_curtas_carreira.png")

# %% [markdown]
# #QUESTÃO 5 - GRUPO 1

# %% [markdown]
# Nesta questão, utilizamos um dataframe com os álbuns mais premiados.

# %% [markdown]
# ##Álbuns mais premiados

# %%
df_premiadas = pd.read_csv("./dataframe_premiadas.csv")
df_premiadas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Álbum    5 non-null      object
#  1   Prêmios  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
#Álbum mais premiado
df_premiadas = pd.read_csv("./dataframe_premiadas.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=df_premiadas, x="Prêmios", y="Álbum",
            palette = ("autumn")).set(title = "Álbuns Mais Premiados")
plt.savefig("albuns_mais_premiados.png")

# %% [markdown]
# #QUESTÃO 6 - GRUPO 1

# %% [markdown]
# ### Relação entre popularidade e duração

# %%
df_pop_d = pd.read_csv("./dataframe_seu-jorge.csv")
sns.jointplot(x = 'Popularidade', y = 'Duração', 
              data = df_pop_d, kind = 'reg')
plt.savefig("popularidade_vs_duração.png")

# %% [markdown]
# Resposta: Devido à grande dispersão dos dados, não havendo proximidade dos dados em relação a reta, é possível concluir que não há relação entre a duração da música e sua popularidade.

# %% [markdown]
# #QUESTÃO 1 - GRUPO 3

# %% [markdown]
# ##1) Álbum América Brasil

# %%
dfAB_mais_populares = pd.read_csv("./dataframe_popularidade_América Brasil.csv") 
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAB_mais_populares, x="Popularidade", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum América Brasil - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum América Brasil Mais Populares
dfAB_mais_populares = pd.read_csv("./dataframe_popularidade_América Brasil.csv") 
dfAB_mais_populares = dfAB_mais_populares.head(5)
fig, ax=plt.subplots(figsize=(16,6))
sns.barplot(data=dfAB_mais_populares, x="Popularidade", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Mais Populares")
plt.savefig("mais_populares_AméricaBrasil.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum América Brasil Menos Populares
dfAB_menos_populares = pd.read_csv("./dataframe_popularidade_América Brasil.csv")
dfAB_menos_populares = dfAB_menos_populares.tail(5)
dfAB_menos_populares2 = dfAB_menos_populares.sort_values('Popularidade')
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAB_menos_populares2, x="Popularidade", y="Música", 
            palette = ("Oranges_r")).set(title = "Álbum América Brasil - Menos Populares") 
plt.savefig("menos_populares_AméricaBrasil.png")

# %% [markdown]
# ##2) Álbum América Brasil Ao Vivo

# %%
dfABv = pd.read_csv("./dataframe_popularidade_América Brasil (Ao Vivo).csv") 
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfABv, x="Popularidade", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum América Brasil Ao Vivo - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum América Brasil Ao Vivo Mais Populares
dfABv = pd.read_csv("./dataframe_popularidade_América Brasil (Ao Vivo).csv") 
dfABv_mais_populares  = dfABv.head(5)
fig, ax=plt.subplots(figsize=(17,6))
sns.barplot(data=dfABv_mais_populares, x="Popularidade", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Mais Populares") 
plt.savefig("mais_populares_AméricaBrasilAoVivo.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum América Brasil Ao Vivo Menos Populares
dfABv_menos_populares = dfABv_mais_populares.tail(4)
dfABv_menos_populares2 = dfABv_menos_populares.sort_values('Popularidade')
fig, ax=plt.subplots(figsize=(17,6))
sns.barplot(data=dfABv_menos_populares2, x="Popularidade", y="Música", 
            palette = ("Greens_r")).set(title = "Álbum América Brasil Ao Vivo - Menos Populares") 
plt.savefig("menos_populares_AméricaBrasilAoVivo.png")

# %% [markdown]
# ##3) Álbum Ana e Jorge

# %%
dfAJ2 = pd.read_csv("./dataframe_popularidade_Ana e Jorge.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAJ_mais_populares, x="Popularidade", y="Música", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Ana e Jorge - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Ana e Jorge Mais Populares
dfAJ2 = pd.read_csv("./dataframe_popularidade_Ana e Jorge.csv")
dfAJ_mais_populares = dfAJ2.head(3)
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfAJ_mais_populares, x="Popularidade", y="Música", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge - Mais Populares") 
plt.savefig("mais_populares_AnaeJorge.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Ana e Jorge Menos Populares
dfAJ_menos_populares = dfAJ2.tail(3)
dfAJ_menos_populares2 = dfAJ_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfAJ_menos_populares2, x="Popularidade", y="Música", 
            palette = ("Reds_r")).set(title = "Álbum Ana e Jorge - Menos Populares") 
plt.savefig("menos_populares_AnaeJorge.png")

# %% [markdown]
# ##4) Álbum Cru

# %%
dfCp= pd.read_csv("./dataframe_popularidade_Cru.csv")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfCp, x="Popularidade", y="Música", 
            palette = ("Purples_r")).set(title = "Álbum Cru - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Cru - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Cru mais populares
dfCp= pd.read_csv("./dataframe_popularidade_Cru.csv")
dfCp_mais_populares = dfCp.head(4)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfCp_mais_populares, x="Popularidade", y="Música", 
            palette = ("Purples_r")).set(title = "Álbum Cru - Mais Populares") 
plt.savefig("mais_populares_Cru.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Cru Menos Populares  
dfCp_menos_populares = dfCp.tail(4)
dfCp_menos_populares2 = dfCp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfCp_menos_populares2, x="Popularidade", y="Música", 
            palette = ("Purples_r")).set(title = "Álbum Cru - Menos Populares")
plt.savefig("menos_populares_Cru.png")

# %% [markdown]
# ## 5) Álbum MTV Apresenta Seu Jorge

# %%
dfMTVp = pd.read_csv("./dataframe_popularidade_MTV Apresenta Seu Jorge.csv")
fig, ax=plt.subplots(figsize=(10,6))
sns.barplot(data=dfMTVp, x="Popularidade", y="Música", 
            palette = ("RdBu_r")).set(title = "MTV Apresenta Seu Jorge - Popularidade")
# Out:
# [Text(0.5, 1.0, 'MTV Apresenta Seu Jorge - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum MTV Apresenta Seu Jorge Mais Populares
dfMTVp = pd.read_csv("./dataframe_popularidade_MTV Apresenta Seu Jorge.csv")
dfMTVp_mais_populares = dfMTVp.head(4)
fig, ax=plt.subplots(figsize=(20,6))
sns.barplot(data=dfMTVp_mais_populares, x="Popularidade", y="Música", 
            palette = ("RdBu_r")).set(title = "MTV Apresenta Seu Jorge - Mais Populares") 
plt.savefig("mais_populares_MTVApresentaSeuJorge.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum MTV Apresenta Seu Jorge Menos Populares
dfMTVp_menos_populares = dfMTVp.tail(4)
dfMTVp_menos_populares2 = dfMTVp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(20,6))
sns.barplot(data=dfMTVp_menos_populares2 ,x="Popularidade", y="Música",
            palette = ("RdBu_r")).set(title = "Álbum MTV Apresenta Seu Jorge - Menos Populares")
plt.savefig("menos_populares_MTVApresentaSeuJorge.png")

# %% [markdown]
# ##6) Álbum Músicas Para Churrasco (vol.1)

# %%
dfMCp = pd.read_csv("./dataframe_popularidade_Músicas Para Churrasco (vol.1).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMCp, x="Popularidade", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.1) - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Músicas Para Churrasco (vol 1) Mais Populares
dfMCp = pd.read_csv("./dataframe_popularidade_Músicas Para Churrasco (vol.1).csv")
dfMCp_mais_populares = dfMCp.head(5)
fig, ax=plt.subplots(figsize=(16,8))
sns.barplot(data=dfMCp_mais_populares, x="Popularidade", y="Música", 
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Mais Populares")
plt.savefig("mais_populares_MusicasParaChurrasco(vol1).png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Músicas Para Churrasco (vol 1) Menos Populares
dfMCp_menos_populares = dfMCp.tail(4)
dfMCp_menos_populares2 = dfMCp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(16,6))
sns.barplot(data=dfMCp_menos_populares2, x="Popularidade", y="Música",
            palette = ("PuBu_r")).set(title = "Álbum Músicas Para Churrasco (vol.1) - Menos Populares") 
plt.savefig("menos_populares_MusicasParaChurrasco(vol1).png")

# %% [markdown]
# ## 7) Álbum Músicas Para Churrasco (vol.2)

# %%
dfMC2p = pd.read_csv("./dataframe_popularidade_Músicas Para Churrasco (vol.2).csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfMC2p, x="Popularidade", y="Música", 
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Músicas Para Churrasco (vol.2) - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Músicas Para Churrasco (vol 2) Mais Populares
dfMC2p = pd.read_csv("./dataframe_popularidade_Músicas Para Churrasco (vol.2).csv")
dfMC2p_mais_populares = dfMC2p.head(5)
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(data=dfMC2p_mais_populares, x="Popularidade", y="Música", 
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) - Mais Populares") 
plt.savefig("mais_populares_MusicasParaChurrasco(vol2).png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Músicas Para Churrasco (vol.2) Menos Populares
dfMC2p_menos_populares = dfMC2p.tail(4)
dfMC2p_menos_populares2 = dfMC2p_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(16,6))
sns.barplot(data=dfMC2p_menos_populares2, x="Popularidade", y="Música",
            palette = ("RdPu_r")).set(title = "Álbum Músicas Para Churrasco (vol.2) Menos Populares")
plt.savefig("menos_populares_MusicasParaChurrasco(vol2).png")

# %% [markdown]
# ## 8) Álbum Night Dreamer Direct-to-disc Sessions

# %%
dfNDp = pd.read_csv("./dataframe_popularidade_Night Dreamer Direct-to-disc Sessions.csv")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfNDp, x="Popularidade", y="Música",
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Night Dreamer Direct-to-disc Sessions - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Night Dreamer Direct-to-disc Sessions Mais Populares
dfNDp = pd.read_csv("./dataframe_popularidade_Night Dreamer Direct-to-disc Sessions.csv")
dfNDp_mais_populares = dfNDp.head(4)
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfNDp_mais_populares, x="Popularidade", y="Música",
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions - Mais Populares") 
plt.savefig("mais_populares_NightDreamer.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Night Dreamer Direct-to-disc Sessions Menos Populares 
dfNDp_menos_populares = dfNDp.tail(3)
dfNDp_menos_populares2 = dfNDp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfNDp_menos_populares2, x="Popularidade", y="Música",
            palette = ("cool_r")).set(title = "Álbum Night Dreamer Direct-to-disc Sessions - Menos Populares") 
plt.savefig("menos_populares_NightDreamer.png")

# %% [markdown]
# ## 9) Álbum Samba Esporte Fino

# %%
dfSEFp = pd.read_csv("./dataframe_popularidade_Samba Esporte Fino.csv")
fig, ax=plt.subplots(figsize=(14,8))
sns.barplot(data=dfSEFp, x="Popularidade", y="Música", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Samba Esporte Fino - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Samba Esporte Fino Mais Populares
dfSEFp = pd.read_csv("./dataframe_popularidade_Samba Esporte Fino.csv")
dfSEFp_mais_populares = dfSEFp.head(4)
fig, ax=plt.subplots(figsize=(19,8))
sns.barplot(data=dfSEFp_mais_populares, x="Popularidade", y="Música", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino - Mais Populares") 
plt.savefig("mais_populares_SambaEsporteFino.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Samba Esporte Fino Menos Populares
dfSEFp_menos_populares = dfSEFp.tail(3)
dfSEFp_menos_populares2 = dfSEFp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(14,8))
sns.barplot(data=dfSEFp_menos_populares2, x="Popularidade", y="Música", 
            palette = ("coolwarm_r")).set(title = "Álbum Samba Esporte Fino - Menos Populares") 
plt.savefig("menos_populares_SambaEsporteFino.png")

# %% [markdown]
# ## 10) Álbum Perfil

# %%
dfPp = pd.read_csv("./dataframe_popularidade_Perfil.csv")
fig, ax=plt.subplots(figsize=(12,6))
sns.barplot(data=dfPp, x="Popularidade", y="Música", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum Perfil - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum Perfil Mais Populares
dfPp = pd.read_csv("./dataframe_popularidade_Perfil.csv")
dfPp_mais_populares = dfPp.head(5)
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(data=dfPp_mais_populares, x="Popularidade", y="Música", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil - Mais Populares") 
plt.savefig("mais_populares_Perfil.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum Perfil Menos Populares
dfPp_menos_populares = dfPp.tail(4)
dfPp_menos_populares2 = dfPp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(14,6))
sns.barplot(data=dfPp_menos_populares2, x="Popularidade", y="Música", 
            palette = ("OrRd_r")).set(title = "Álbum Perfil - Menos Populares") 
plt.savefig("menos_populares_Perfil.png")

# %% [markdown]
# ##11) Álbum The Life Aquatic Studio

# %%
dfLAp = pd.read_csv("./dataframe_popularidade_The Life Aquatic Studio Sessions.csv")
fig, ax=plt.subplots(figsize=(12,8))
sns.barplot(data=dfLAp_mais_populares, x="Popularidade", y="Música",
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions - Popularidade")
# Out:
# [Text(0.5, 1.0, 'Álbum The Life Aquatic Studio Sessions - Popularidade')]

# %% [markdown]
# ### Músicas mais populares

# %%
#Álbum The Life Aquatic Studio Sessions Mais Populares
dfLAp = pd.read_csv("./dataframe_popularidade_The Life Aquatic Studio Sessions.csv")
dfLAp_mais_populares = dfLAp.head(3)
fig, ax=plt.subplots(figsize=(14,8))
sns.barplot(data=dfLAp_mais_populares, x="Popularidade", y="Música", 
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions - Mais Populares") 
plt.savefig("mais_populares_TheLifeAquaticStudioSessions.png")

# %% [markdown]
# ### Músicas menos populares

# %%
#Álbum The Life Aquatic Studio Sessions Menos Populares
dfLAp_menos_populares = dfLAp.tail(3)
dfLAp_menos_populares2 = dfLAp_menos_populares.sort_values("Popularidade")
fig, ax=plt.subplots(figsize=(18,6))
sns.barplot(data=dfLAp_menos_populares2, x="Popularidade", y="Música", 
            palette = ("Spectral")).set(title = "Álbum The Life Aquatic Studio Sessions Menos Populares") 
plt.savefig("menos_populares_TheLifeAquaticStudioSessions.png")

# %% [markdown]
# #QUESTÃO 2 - GRUPO 3

# %% [markdown]
# Nesta questão, utilizamos dois dataframes, um com as músicas mais populares e outro com as músicas menos populares da carreira do Seu Jorge. No gráfico das músicas menos populares, assim como nas outras questões, ordenamos de maneira crescente, enquanto no gráfico de músicas mais populares, ordenamos de maneira decrescente.

# %% [markdown]
# ###Músicas mais populares

# %%
#Músicas mais populares da carreira do Seu Jorge
df_mais_populares = pd.read_csv("./dataframe_mais_populares.csv") 
fig, ax=plt.subplots(figsize=(16,8))
sns.barplot(data=df_mais_populares, x= "Popularidade", y="Música",
            palette = ("Paired")).set(title = "Músicas Mais Populares da Carreira do Seu Jorge")
plt.savefig("mais_populares_carreira.png")

# %% [markdown]
# ###Músicas menos populares

# %%
#Músicas menos populares da carreira do Seu Jorge
df_menos_populares = pd.read_csv("./dataframe_menos_populares.csv") 
fig, ax=plt.subplots(figsize=(19,8))
df_menos_populares1 = df_menos_populares.sort_values('Popularidade') #inverter a ordem começando do menor para o maior valor
sns.barplot(data=df_menos_populares1, x= "Popularidade", y="Música",
            palette = ("Paired")).set(title = "Músicas Menos Populares da Carreira do Seu Jorge")
plt.savefig("menos_populares_carreira.png")

# %% [markdown]
# #QUESTÃO 3 - GRUPO 3

# %% [markdown]
# ###Músicas menos ouvidas x músicas menos populares
#
# Comparando os gráficos, podemos perceber que não há compatibilidade em nenhuma das músicas classificadas como menos ouvidas e menos populares.

# %% [markdown]
# ###Músicas mais ouvidas x músicas mais populares
# Comparando os gráficos, podemos perceber alguma compatibilidade entre algumas músicas mais populares e músicas mais ouvidas.
# Ressaltando, em primeiro lugar, as músicas que aparecem em ambas as classificações, podemos comparar a posição no ranking: enquanto a música "Amiga da Minha Mulher" é apontada como a primeira em popularidade, aparece apenas como a quinta mais ouvida. A segunda música mais popular "Felicidade" não aparece na relação de músicas mais ouvidas. "Mina do Condomínio" é a terceira mais popular e quarta mais ouvida. "São Gonça" é a quarta mais popular e sétima mais ouvida. "Quem não quer sou eu" é a quinta mais popular e sexta mais ouvida. Entretanto, as músicas mais populares a partir da quinta colocação não aparecem nas músicas mais ouvidas. Além disso, a segunda e terceira músicas mais ouvida "Burguesinha" e "Carolina" não aparecem nas músicas populares, o mesmo vale para a para a oitava e a nona músicas mais ouvidas, "Tive Razão" e "Pessoal particular".
